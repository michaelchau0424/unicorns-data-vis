# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv('./data/Unicorn_Companies_clean.csv')

# %%
df
# Out:
#       Unnamed: 0       Company Valuation ($B) Date Joined        Country  \
# 0              0     Bytedance           $140   4/07/2017          China
# 1              1        SpaceX        $100.30  12/01/2012  United States
# 2              2        Stripe            $95   1/23/2014  United States
# 3              3        Klarna         $45.60  12/12/2011         Sweden
# 4              4    Epic Games            $42  10/26/2018  United States
# ...          ...           ...            ...         ...            ...
# 1032        1032     Timescale             $1   2/22/2022  United States
# 1033        1033      Scalapay             $1   2/23/2022          Italy
# 1034        1034  Omada Health             $1   2/23/2022  United States
# 1035        1035    BlueVoyant             $1   2/23/2022  United States
# 1036        1036          Veev             $1   2/24/2022  United States
#
#                City                      Industry  \
# ...

# %%
df.Industry.unique()
# Out:
# array(['Artificial intelligence', 'Other', 'Fintech',
#        'Internet software & services',
#        'Supply chain, logistics, & delivery',
#        'Data management & analytics',
#        'Sequoia Capital, Thoma Bravo, Softbank',
#        'E-commerce & direct-to-consumer', 'Edtech', 'Hardware',
#        'Consumer & retail', 'Health', 'Auto & transportation', 'Finttech',
#        'Cybersecurity', 'Mobile & telecommunications', 'Travel',
#        'Kuang-Chi',
#        'Tiger Global Management, Tiger Brokers, DCM Ventures',
#        'Jungle Ventures, Accel, Venture Highway',
#        'Artificial Intelligence',
#        'Vision Plus Capital, GSR Ventures, ZhenFund',
#        'Hopu Investment Management, Boyu Capital, DC Thomson Ventures',
#        '500 Global, Rakuten Ventures, Golden Gate Ventures',
#        'Sequoia Capital China, ING, Alibaba Entrepreneurs Fund',
#        'Sequoia Capital China, Shunwei Capital Partners, Qualgro',
# ...

# %%
df['Industry'] = df['Industry'].replace(['Artificial intelligence'],'Artificial Intelligence')

# %%
df.Industry.unique()
# Out:
# array(['Artificial Intelligence', 'Other', 'Fintech',
#        'Internet software & services',
#        'Supply chain, logistics, & delivery',
#        'Data management & analytics',
#        'Sequoia Capital, Thoma Bravo, Softbank',
#        'E-commerce & direct-to-consumer', 'Edtech', 'Hardware',
#        'Consumer & retail', 'Health', 'Auto & transportation', 'Finttech',
#        'Cybersecurity', 'Mobile & telecommunications', 'Travel',
#        'Kuang-Chi',
#        'Tiger Global Management, Tiger Brokers, DCM Ventures',
#        'Jungle Ventures, Accel, Venture Highway',
#        'Vision Plus Capital, GSR Ventures, ZhenFund',
#        'Hopu Investment Management, Boyu Capital, DC Thomson Ventures',
#        '500 Global, Rakuten Ventures, Golden Gate Ventures',
#        'Sequoia Capital China, ING, Alibaba Entrepreneurs Fund',
#        'Sequoia Capital China, Shunwei Capital Partners, Qualgro',
#        'Dragonfly Captial, Qiming Venture Partners, DST Global',
# ...

# %%
df.loc[df['Industry'] =="Kuang-Chi"]
# Out:
#      Unnamed: 0    Company Valuation ($B) Date Joined    Country  \
# 217         217  HyalRoute          $3.50   5/26/2020  Singapore
#
#                             City   Industry Select Inverstors Founded Year  \
# 217  Mobile & telecommunications  Kuang-Chi              None         2015
#
#     Total Raised Investors Count                    False
# 217     $263.12M               1  Artificial Intelligence

# %%
df.loc[df['Select Inverstors']== 'None']
# Out:
#       Unnamed: 0                     Company Valuation ($B) Date Joined  \
# 10            10                         FTX            $32   7/20/2021
# 217          217                   HyalRoute          $3.50   5/26/2020
# 292          292                 Amber Group             $3   6/21/2021
# 318          318                      Moglix          $2.60   5/17/2021
# 438          438  Advance Intelligence Group             $2   9/23/2021
# 639          639                        Trax          $1.30   7/22/2019
# 757          757                   Carousell          $1.10   9/15/2021
# 789          789            LinkSure Network             $1   1/01/2015
# 814          814                       WeLab             $1  11/08/2017
# 882          882                     PatSnap             $1   3/16/2021
# 911          911                  Matrixport          $1.05   6/01/2021
# 916          916                       Carro             $1   6/14/2021
# ...

# %%
#df['Industry'] = df['Industry'].replace(['Artificial intelligence'],'Artificial Intelligence')

df_a = df.loc[df['Select Inverstors']!= 'None']

# %%
df_a['Date Joined'].astype(str)
# Out:
# 0        4/07/2017
# 1       12/01/2012
# 2        1/23/2014
# 3       12/12/2011
# 4       10/26/2018
#            ...
# 1032     2/22/2022
# 1033     2/23/2022
# 1034     2/23/2022
# 1035     2/23/2022
# 1036     2/24/2022
# Name: Date Joined, Length: 1020, dtype: object

# %%
df_a['Date Joined'] = pd.to_datetime(df['Date Joined'])

# %%
df_a['YearJoined'] = df_a['Date Joined'].dt.year

# %%
df_a
# Out:
#       Unnamed: 0       Company Valuation ($B) Date Joined        Country  \
# 0              0     Bytedance           $140  2017-04-07          China
# 1              1        SpaceX        $100.30  2012-12-01  United States
# 2              2        Stripe            $95  2014-01-23  United States
# 3              3        Klarna         $45.60  2011-12-12         Sweden
# 4              4    Epic Games            $42  2018-10-26  United States
# ...          ...           ...            ...         ...            ...
# 1032        1032     Timescale             $1  2022-02-22  United States
# 1033        1033      Scalapay             $1  2022-02-23          Italy
# 1034        1034  Omada Health             $1  2022-02-23  United States
# 1035        1035    BlueVoyant             $1  2022-02-23  United States
# 1036        1036          Veev             $1  2022-02-24  United States
#
#                City                      Industry  \
# ...

# %%
df_a.groupby(['Industry']).count()
# Out:
#                                      Unnamed: 0  Company  Valuation ($B)  \
# Industry
# Artificial Intelligence                      78       78              78
# Auto & transportation                        29       29              29
# Consumer & retail                            25       25              25
# Cybersecurity                                49       49              49
# Data management & analytics                  41       41              41
# E-commerce & direct-to-consumer             107      107             107
# Edtech                                       28       28              28
# Fintech                                     205      205             205
# Finttech                                      1        1               1
# Hardware                                     33       33              33
# Health                                       69       69              69
# Internet software & services                192      192             192
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-1af97563c6d6> in <module>
# ----> 1 df_a.value()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value'

# %%
df_a.set_axis(['NumberOfUnicorns'], axis=1, inplace=True)

# %%
df_a
# Out:
#                                     NumberOfUnicorns
# Industry                YearJoined
# Artificial Intelligence 2012                       1
#                         2015                       2
#                         2016                       1
#                         2017                       4
#                         2018                      13
# ...                                              ...
# Travel                  2017                       2
#                         2018                       4
#                         2019                       3
#                         2021                       3
#                         2022                       1
#
# [124 rows x 1 columns]

# %%
df_a.to_csv('./data/Unicorn_Companies_clean2.csv')

# %%
df_a = df_a.iloc[:,0:1]

# %%
df_a = df_a.groupby(['Industry', 'YearJoined']).count()

# %%
df2 = df.loc[df['Select Inverstors']== 'None', ['Country','City', 'Industry', 'Select Inverstors']]
df.loc[df['Select Inverstors']== 'None', ['Country','City', 'Industry', 'Select Inverstors']]['Select Inverstors'] = df.loc[df['Select Inverstors']== 'None', ['Country','City', 'Industry', 'Select Inverstors']]['Select Inverstors'].replace('None', df['Industry'])

# %%
df.loc[df['Select Inverstors']== 'None', ['Country','City', 'Industry', 'Select Inverstors']]['Industry'] = df.loc[df['Select Inverstors']== 'None', ['Country','City', 'Industry', 'Select Inverstors']]['City']

# %%
df.loc[df['Select Inverstors']== 'None', ['Country','City', 'Industry', 'Select Inverstors']]['City'] = 'None'

# %%
df.loc[df['Select Inverstors']== 'None', ['Country','City', 'Industry', 'Select Inverstors']].loc[df.loc[df['Select Inverstors']== 'None', ['Country','City', 'Industry', 'Select Inverstors']]["Industry"] == "Shanghai", ['City']] = df.loc[df['Select Inverstors']== 'None', ['Country','City', 'Industry', 'Select Inverstors']].loc[df2["Industry"] == "Shanghai", ['Industry']]

# %%
df.loc[df['Select Inverstors']== 'None', ['Country','City', 'Industry', 'Select Inverstors']]
# Out:
#         Country                                 City  \
# 10      Bahamas                              Fintech
# 217   Singapore          Mobile & telecommunications
# 292   Hong Kong                              Fintech
# 318   Singapore      E-commerce & direct-to-consumer
# 438   Singapore              Artificial intelligence
# 639   Singapore              Artificial intelligence
# 757   Singapore      E-commerce & direct-to-consumer
# 789       China                             Shanghai
# 814   Hong Kong                              Fintech
# 882   Singapore         Internet software & services
# 911   Singapore                              Fintech
# 916   Singapore      E-commerce & direct-to-consumer
# 928   Singapore                              Fintech
# 939   Singapore                              Fintech
# 951   Hong Kong      E-commerce & direct-to-consumer
# 963   Singapore  Supply chain, logistics, & delivery
# 1014  Singapore         Internet software & services
#
# ...

# %%
df.loc[df['Industry']=='Fintech']
# Out:
#       Unnamed: 0       Company Valuation ($B) Date Joined         Country  \
# 2              2        Stripe            $95   1/23/2014   United States
# 3              3        Klarna         $45.60  12/12/2011          Sweden
# 6              6  Checkout.com            $40   5/02/2019  United Kingdom
# 9              9       Revolut            $33   4/26/2018  United Kingdom
# 12            12         Chime            $25   3/05/2019   United States
# ...          ...           ...            ...         ...             ...
# 1004        1004         Lydia             $1  12/08/2021          France
# 1017        1017          CAIS             $1   1/11/2022   United States
# 1023        1023         Esusu             $1   1/27/2022   United States
# 1027        1027       Payhawk             $1   2/14/2022  United Kingdom
# 1033        1033      Scalapay             $1   2/23/2022           Italy
#
#                City Industry  \
# 2     San Francisco  Fintech
# ...
