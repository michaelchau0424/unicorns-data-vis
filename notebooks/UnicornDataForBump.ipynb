# %%
import pandas as pd

# %%
df = pd.read_csv("../data/Unicorn_Companies_clean2.csv")

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1       Company  Valuation ($B) Date Joined  \
# 0              0             0     Bytedance           140.0  2017-04-07
# 1              1             1        SpaceX           100.3  2012-12-01
# 2              2             2        Stripe            95.0  2014-01-23
# 3              3             3        Klarna            45.6  2011-12-12
# 4              4             4    Epic Games            42.0  2018-10-26
# ...          ...           ...           ...             ...         ...
# 1015        1032          1032     Timescale             1.0  2022-02-22
# 1016        1033          1033      Scalapay             1.0  2022-02-23
# 1017        1034          1034  Omada Health             1.0  2022-02-23
# 1018        1035          1035    BlueVoyant             1.0  2022-02-23
# 1019        1036          1036          Veev             1.0  2022-02-24
#
#             Country           City                      Industry  \
# ...

# %%
top5 = df.groupby("Industry").sum().sort_values('NumberOfUnicorns', ascending=False)
#Fintech, Internet software & services, E-commerce & direct-to-consumer, Artificial Intelligence, Health
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-ec331430df0f> in <module>
# ----> 1 top5 = df.groupby("Industry").sum().sort_values('NumberOfUnicorns', ascending=False)
#       2 #Fintech, Internet software & services, E-commerce & direct-to-consumer, Artificial Intelligence, Health
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4991
#    4992             by = by[0]
# -> 4993             k = self._get_label_or_level_values(by, axis=axis)
#    4994
#    4995             if isinstance(ascending, (tuple, list)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
# ...

# %%
df_top5 = df.loc[df["Industry"].isin(["Fintech", "Internet software & services", "E-commerce & direct-to-consumer", "Artificial Intelligence", "Health"])]

# %%
df_top5["rank"] = df_top5.groupby("YearJoined")["NumberOfUnicorns"].rank("first", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-824a5bf18426> in <module>
# ----> 1 df_top5["rank"] = df_top5.groupby("YearJoined")["NumberOfUnicorns"].rank("first", ascending=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     266         else:
#     267             if key not in self.obj:
# --> 268                 raise KeyError("Column not found: {key}".format(key=key))
#     269             return self._gotitem(key, ndim=1)
#     270
#
# KeyError: 'Column not found: NumberOfUnicorns'

# %%
df_top5 = df_top5.loc[df_top5["YearJoined"] > 2014]

# %%
df_top5.sort_values("YearJoined")
# Out:
#                            Industry  YearJoined  NumberOfUnicorns  rank
# 1           Artificial Intelligence        2015                 2   3.0
# 58                          Fintech        2015                 2   4.0
# 84     Internet software & services        2015                 4   2.0
# 40  E-commerce & direct-to-consumer        2015                 9   1.0
# 74                           Health        2015                 2   5.0
# 85     Internet software & services        2016                 1   4.0
# 41  E-commerce & direct-to-consumer        2016                 6   1.0
# 75                           Health        2016                 1   3.0
# 2           Artificial Intelligence        2016                 1   2.0
# 86     Internet software & services        2017                 4   5.0
# 3           Artificial Intelligence        2017                 4   2.0
# 76                           Health        2017                 4   4.0
# ...

# %%
df_top5
# Out:
#                            Industry YearJoined  NumberOfUnicorns  rank
# 0                           Fintech 2016-01-01                 0   3.0
# 2           Artificial Intelligence 2015-01-01                 2   3.0
# 3           Artificial Intelligence 2016-01-01                 1   2.0
# 4           Artificial Intelligence 2017-01-01                 4   2.0
# 5           Artificial Intelligence 2018-01-01                13   2.0
# 6           Artificial Intelligence 2019-01-01                13   2.0
# 7           Artificial Intelligence 2020-01-01                 3   5.0
# 8           Artificial Intelligence 2021-01-01                34   5.0
# 9           Artificial Intelligence 2022-01-01                 7   3.0
# 41  E-commerce & direct-to-consumer 2015-01-01                 9   1.0
# 42  E-commerce & direct-to-consumer 2016-01-01                 6   1.0
# 43  E-commerce & direct-to-consumer 2017-01-01                 4   3.0
# ...

# %%
df_top5.loc[-1] = ["Fintech",2016, 0, 3.0]  # adding a row
df_top5.index = df_top5.index + 1  # shifting index
df_top5 = df_top5.sort_index()  # sorting by index

# %%
df_top5.dtypes
# Out:
# Industry                    object
# YearJoined          datetime64[ns]
# NumberOfUnicorns             int64
# rank                       float64
# dtype: object

# %%
df_top5['YearJoined'] = pd.to_datetime(df_top5['YearJoined'], format='%Y')

# %%
df_top5.to_csv("../data/UnicornDataForBump.csv")
