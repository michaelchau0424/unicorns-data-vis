# %%
import pandas as pd

# %%
df = pd.read_csv("../data/Unicorn_Companies_clean.csv")

# %%
df
# Out:
#       Unnamed: 0       Company Valuation ($B) Date Joined        Country  \
# 0              0     Bytedance           $140   4/07/2017          China
# 1              1        SpaceX        $100.30  12/01/2012  United States
# 2              2        Stripe            $95   1/23/2014  United States
# 3              3        Klarna         $45.60  12/12/2011         Sweden
# 4              4    Epic Games            $42  10/26/2018  United States
# ...          ...           ...            ...         ...            ...
# 1032        1032     Timescale             $1   2/22/2022  United States
# 1033        1033      Scalapay             $1   2/23/2022          Italy
# 1034        1034  Omada Health             $1   2/23/2022  United States
# 1035        1035    BlueVoyant             $1   2/23/2022  United States
# 1036        1036          Veev             $1   2/24/2022  United States
#
#                City                      Industry  \
# ...

# %%
df = df.loc[df["Select Inverstors"] != 'None']

# %%
#remove dollar sign
# data.loc[0:2,['Num','NAME']] = [100,'Python']
df["Valuation ($B)"] = df["Valuation ($B)"].str.strip("$")
df["Valuation ($B)"].astype(float)
# Out:
# C:\Users\micha\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0       140.0
# 1       100.3
# 2        95.0
# 3        45.6
# 4        42.0
#         ...
# 1032      1.0
# 1033      1.0
# 1034      1.0
# 1035      1.0
# 1036      1.0
# Name: Valuation ($B), Length: 1020, dtype: float64

# %%
df.loc[df["Industry"] == "Finttech"]["Industry"] = "Fintech"
# Out:
# C:\Users\micha\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Industry'] = df['Industry'].replace(['Finttech'],'Fintech')
df["Industry"] = df["Industry"].replace(['Artificial intelligence'], 'Artificial Intelligence')
# Out:
# C:\Users\micha\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\micha\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df["Date Joined"] = pd.to_datetime(df["Date Joined"])
# Out:
# C:\Users\micha\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['YearJoined'] = pd.DatetimeIndex(df["Date Joined"]).year
# Out:
# C:\Users\micha\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#       Unnamed: 0       Company Valuation ($B) Date Joined        Country  \
# 0              0     Bytedance            140  2017-04-07          China
# 1              1        SpaceX         100.30  2012-12-01  United States
# 2              2        Stripe             95  2014-01-23  United States
# 3              3        Klarna          45.60  2011-12-12         Sweden
# 4              4    Epic Games             42  2018-10-26  United States
# ...          ...           ...            ...         ...            ...
# 1032        1032     Timescale              1  2022-02-22  United States
# 1033        1033      Scalapay              1  2022-02-23          Italy
# 1034        1034  Omada Health              1  2022-02-23  United States
# 1035        1035    BlueVoyant              1  2022-02-23  United States
# 1036        1036          Veev              1  2022-02-24  United States
#
#                City                      Industry  \
# ...

# %%
df_count = df.groupby(["Industry", "YearJoined"]).count()

# %%
df_count["NumberOfUnicorns"] = df_count["Unnamed: 0"]

# %%
df_count = df_count[['NumberOfUnicorns']]

# %%
df_count['index1'] = df_count.index

# %%
df_count
# Out:
#                                     NumberOfUnicorns  \
# Industry                YearJoined
# Artificial Intelligence 2012                       1
#                         2015                       2
#                         2016                       1
#                         2017                       4
#                         2018                      13
# ...                                              ...
# Travel                  2017                       2
#                         2018                       4
#                         2019                       3
#                         2021                       3
#                         2022                       1
#
#                                                              index1
# Industry                YearJoined
# Artificial Intelligence 2012        (Artificial Intelligence, 2012)
#                         2015        (Artificial Intelligence, 2015)
# ...

# %%
df_count.loc[df_count["YearJoined"] > 2014]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YearJoined'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-8686837a625e> in <module>
# ...
